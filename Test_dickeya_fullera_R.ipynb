# %% [markdown]
# # Dickey Fuller Test
# Test Dickey-Fuller: jest to jeden ze statystycznych testów sprawdzających stacjonarność. Tutaj hipoteza zerowa to, że szereg czasowy jest niestacjonarny.
# Wyniki testu obejmują statystykę testu oraz niektóre wartości krytyczne dla różnych poziomów ufności. Jeśli statystyka testowa jest mniejsza niż  wartość krytyczna, możemy odrzucić hipotezę zerową i powiedzieć, że szereg czasowy jest stacjonarny.

# %%
import numpy as np
import pandas as pd
import scipy
import random
import matplotlib.pylab as plt
from statsmodels.tsa.stattools import adfuller

# %%
x = [0]
np.random.seed(10)
for j in range(1000):
    x.append(x[j] + np.random.normal())

# %%
df=pd.Series(x)
plt.figure(figsize=(12,6))
df.plot()
plt.show()

# %% [markdown]
# # Zadanie 1
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                   -0.630826
# p-value                           0.863863
# Lags Used                         0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64

# %%
_, pval, _, _, _, _ =adfuller(df, autolag='AIC')

# %%
pval
# Out:
# 0.8638634173460656

# %% [markdown]
# # rho=0

# %%
rho=0
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6))
df.plot()
plt.show()

# %% [markdown]
# # Zadanie 2
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                  -31.834439
# p-value                           0.000000
# Lags Used                         0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64

# %% [markdown]
# # rho=0.5

# %%
rho=0.5
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6))
df.plot()
plt.show()

# %% [markdown]
# # Zadanie 3
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                  -19.832802
# p-value                           0.000000
# #Lags Used                        0.000000
# Number of Observations Used    1000.000000
# Critical Value (1%)              -3.436906
# Critical Value (5%)              -2.864435
# Critical Value (10%)             -2.568311
# dtype: float64

# %% [markdown]
# # rho=0.9

# %%
rho=0.9
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6))
df.plot()
plt.show()

# %% [markdown]
# # Zadanie 4
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                -8.029604e+00
# p-value                        1.974573e-12
# Lags Used                      1.000000e+00
# Number of Observations Used    9.990000e+02
# Critical Value (1%)           -3.436913e+00
# Critical Value (5%)           -2.864437e+00
# Critical Value (10%)          -2.568313e+00
# dtype: float64

# %% [markdown]
# # rho=1

# %%
rho=1
x = [0]
for j in range(1000):
    x.append(rho*x[j] + np.random.normal())
df=pd.Series(x)
plt.figure(figsize=(12,6))
df.plot()
plt.show()

# %% [markdown]
# # Zadanie 5
# proszę wykonać Dickey Fuller test dla powyższych danych.

# %%
dftest = adfuller(df, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Test Statistic                  -0.470545
# p-value                          0.897637
# Lags Used                        3.000000
# Number of Observations Used    997.000000
# Critical Value (1%)             -3.436926
# Critical Value (5%)             -2.864443
# Critical Value (10%)            -2.568316
# dtype: float64
